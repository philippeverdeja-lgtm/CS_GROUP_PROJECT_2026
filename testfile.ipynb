# %% [markdown]
# We can test code here

# %%
import pandas as pd

data = {
    "Company": ["Apple", "Microsoft"],
    "PE Ratio": [28.5, 35.2]
}

df = pd.DataFrame(data)
print(df)
# Out:
#      Company  PE Ratio
# 0      Apple      28.5
# 1  Microsoft      35.2
